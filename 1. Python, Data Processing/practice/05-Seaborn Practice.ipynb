# %% [markdown]
# # Seaborn Practice
#
# Referenced Materials :
#
# https://kgptalkie.medium.com/complete-seaborn-python-tutorial-for-data-visualization-in-python-399af0792ef4
#
#
# **Seaborn** is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.
#
# **Statistical analysis** is a process of understanding how variables in a dataset relate to each other and how those relationships depend on other variables. Visualization can be a core component of this process because, when data are visualized properly, the human visual system can see trends and patterns that indicate a relationship.
#
# ## 1. Numerical Data Plotting
# - relplot()
# - scatterplot()
# - lineplot()
#
# ## 2. Categorical Data Plotting
# - catplot()
# - boxplot()
# - stripplot()
# - swarmplot()
#
# ## 3. Visualizing Distribution of the Data
# - displot()
# - kdeplot()
# - jointplot()
# - rugplot()
#
# ## 4. Linear Regression and Relationship
# - regplot()
# - lmplot()
#
# ## 5. Controlling Plotted Figure Aesthetics
# - figure styling
# - axes styling
# - color palettes

# %% [markdown]
# `seaborn` is used to draw various types of graphs.
#
# `numpy` is used to perform basic array operations.
#
# `pyplot` from `matplotlib` is used to visualize the results.
#
# `pandas` is used to read and create the dataset.
#
#
#
# ```
# import seaborn as sns
# import pandas as pd
# import numpy as np
# from numpy.random import randn
# import matplotlib.pyplot as plt
# #%matplotlib inline
# ```

# %%
# Your code here
import seaborn as sns
import pandas as pd
import numpy as np
from numpy.random import randn
import matplotlib.pyplot as plt

# %% [markdown]
# We are going to set the `style` to `darkgrid`.The grid helps the plot serve as a lookup table for quantitative information, and the white-on grey helps to keep the grid from competing with lines that represent data.
#
#
#
# ```
# sns.set(style = 'darkgrid') # style must be one of white, dark, whitegrid, darkgrid, ticks
# ```

# %%
# Your code here
sns.set(style = 'darkgrid')

# %% [markdown]
# Now we are going to load the data using `sns.load_dataset`. Seaborn has some inbuilt dataset. `tips` is the one of them. `tips.tail() `displays the last 5 rows of the dataset
#
#
#
# ```
# tips = sns.load_dataset('tips')
# tips.tail()
# ```

# %%
# Your code here
tips = sns.load_dataset('tips') # test용 seaborn 내장 데이터 
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %% [markdown]
# ---
#
# # 1. Numerical Data Plotting

# %% [markdown]
# Now we will plot the `relational plot` using the `sns.relplot` and visualize the relation between` total_bill` and tip.
#
#
#
# ```
# print(type(tips))
# tips.shape
# ```
#
#
#
# ```
# sns.relplot(x = 'total_bill', y = 'tip', data = tips)
# ```

# %%
# Your code here
print(type(tips))
tips.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (244, 7)

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips) # kind 없으면 기본적으로 산점도로 relation 나타냄

# %% [markdown]
# As you can see, the above plot is a `FacetGrid`. It is a class that maps a dataset onto multiple axes arrayed in a grid of rows and columns that correspond to levels of variables in the dataset.

# %% [markdown]
# Here we have included `smoker` and `time` as well.
# - `hue` groups variable that will produce elements with different colors.
# - `style` groups variable that will produce elements with different styles.
#
#
#
# ```
# sns.relplot (x = 'total_bill', y = 'tip', data = tips, hue = 'smoker', style = 'time')
# ```

# %%
# Your code here
sns.relplot (x = 'total_bill', y = 'tip', data = tips, hue = 'smoker', style = 'time', size = 'size') # hue(색상)

# %% [markdown]
# Here we have used `style` for the `size` variable.
#
#
#
# ```
# sns.relplot(x = 'total_bill', y = 'tip', style = 'size', data = tips)
# ```

# %%
# Your code here
sns.relplot(x = 'total_bill', y = 'tip', style = 'size', data = tips)

# %% [markdown]
# Earlier we have used `hue` for `categorical values` i.e. for smoker.
#
# ---
#
#
# Now we will use `hue` for` numerical values` i.e. for `size`. We can change the `palette` using `cubehelix`.
#
#
#
#
# ```
# sns.relplot(x = 'total_bill', y = 'tip', hue = 'size', data = tips, palette = 'ch:r=-0.8, l= 0.95')
# ```

# %%
# Your code here
sns.relplot(x = 'total_bill', y = 'tip', hue = 'size', data = tips, palette = 'ch:r=-0.5, l= 0.95')

# %% [markdown]
# `size` groups variable that will produce elements with different sizes.
#
# `sizes` is an object that determines how sizes are chosen when `size` is used. Here the smallest circle will be of size 15. The largest circle will be of size 200 and all the others will lie in between.
#
#
#
# ```
# sns.relplot(x = 'total_bill', y = 'tip', data = tips, size = 'size')
# # sns.relplot(x = 'total_bill', y = 'tip', data = tips, size = 'size', sizes = (15, 200))
# ```

# %%
# Your code here
sns.relplot(x = 'total_bill', y = 'tip', data = tips, size = 'size', sizes = (15, 200)) # sizes(min 15, max 200 크기로)
plt.show()

# %%
plt.show()

# %% [markdown]
# Now we will generate a new dataset to plot a `lineplot`.` np.arange()` returns an array with evenly spaced elements. Here it will return values from 0 to 499. `randn()` returns an array of defined shape, filled with random floating-point samples from the standard normal distribution. Here we will get an array of 500 random values. `cumsum()` gives the cumulative sum value.
#
#
#
# ```
# from numpy.random import randn
# df = pd.DataFrame(dict(time = np.arange(500), value = randn(500).cumsum()))
# df.head()
# ```

# %% [markdown]
# By using `kind` we can change the kind of plot drawn. By default, it is set to `scatter`. Now we will change it to `line`.
#
#
#
# ```
# sns.relplot(x = 'time', y = 'value', kind = 'line', data = df, sort = True)
# sns.relplot(x = 'time', y = 'value', kind = 'line', data = df, sort = False)
# ```

# %%
# Your code here
from numpy.random import randn
df = pd.DataFrame(dict(time = np.arange(500), value = randn(500).cumsum()))
df
# Out:
#      time      value
# 0       0  -0.642294
# 1       1  -0.701894
# 2       2  -1.672086
# 3       3  -3.327407
# 4       4  -4.001087
# ..    ...        ...
# 495   495 -18.865548
# 496   496 -17.416866
# 497   497 -17.591598
# 498   498 -15.819846
# 499   499 -15.022714
#
# [500 rows x 2 columns]

# %%
sns.relplot(x = 'time', y = 'value', kind = 'line', data = df, sort = True)

# %%
sns.relplot(x = 'time', y = 'value', kind = 'line', data = df, sort = False) # dict이므로 key인 time에 따라 이미 정렬되어 있기 때문에 변화 없음

# %% [markdown]
# In the above data, the values in time are sorted. Let's see what happens if the values are not sorted. For this, we will create a new dataset.
#
#
# ```
# df = pd.DataFrame(randn(500, 2).cumsum(axis = 0), columns = ['time', 'value'])
# df.head()
# ```

# %%
# Your code here
df = pd.DataFrame(randn(500, 2).cumsum(axis = 0), columns = ['time', 'value'])
df.head()
# Out:
#        time     value
# 0 -0.139283  1.021891
# 1  1.068618  1.171428
# 2  0.220887  0.268085
# 3 -0.063168 -0.312658
# 4  0.168583 -2.436441

# %% [markdown]
# Below we have drawn the plot with unsorted values of the time. You can even draw the plot with sorted values of time by setting `sort = True` which will sort the values of the x-axis.
#
#
#
# ```
# sns.relplot(x = 'time', y = 'value', kind = 'line', data = df, sort = False)
# ```

# %%
# Your code here
sns.relplot(x = 'time', y = 'value', kind = 'line', data = df, sort = False) # 정렬되지 않은 선 그래프를 그리면 뒤죽박죽 엉망

# %%
sns.relplot(x = 'time', y = 'value', kind = 'line', data = df, sort = True) # 데이터에서 정렬이 필요한 경우 옵션으로 줄 수 있음 > time별로 정렬됨(x축 기준)

# %% [markdown]
# Let's go ahead to aggregations and representing the uncertainty to the dataset. This comes into a sensor variable. For same multiple measurements, we get multiple measurements and those measurements are not exactly equal. They are a little deviated from the true value.(noise)
#
# Let's see how we can plot those type of the data with Seaborn.

# %% [markdown]
# Now we will load the fmri dataset.
#
#
#
# ```
# fmri = sns.load_dataset('fmri')
# fmri.head()
# ```

# %%
# Your code here
fmri = sns.load_dataset('fmri')
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %% [markdown]
# As you can see in the dataset same values `timepoint` have different corresponding values of signal. If we draw such a plot we get a `confidence interval` with 95% confidence. To remove the confidence interval we can set `ci = False`
#
#
#
# ```
# sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri, ci = 'sd')
# # sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri, ci = 'False')
# ```

# %%
# Your code here
sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri, ci = 'sd') 
# ci(confidence interval): 신뢰구간, sd(표준편차)

# %%
sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri)

# %%
sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri, ci = False) # ci = False 신뢰구간 안나타냄

# %% [markdown]
# If we want to plot data without any confidence interval we can set `estimator = None`. This will plot the real dataset.
#
#
#
# ```
# sns.relplot(x = 'timepoint', y = 'signal', estimator = None, kind = 'line', data = fmri)
# ```

# %%
# Your code here
sns.relplot(x = 'timepoint', y = 'signal', estimator = None, data = fmri) # 신뢰구간 설정하지 않고 데이터 볼 때

# %%
# Your code here
sns.relplot(x = 'timepoint', y = 'signal', estimator = None, kind = 'line', data = fmri) # 신뢰구간 설정하지 않고 데이터 볼 때

# %%
sns.relplot(x = 'timepoint', y = 'signal', estimator = np.mean, kind = 'line', data = fmri) 
# 같은 timepoint인 signal에 대해 어떻게 계산해서 나타낼 것인가?

# %% [markdown]
# Now we can add a third variable using hue = 'event'.
#
#
#
# ```
# sns.relplot(x = 'timepoint', y = 'signal', hue = 'event', kind = 'line', data = fmri)
# ```

# %%
# Your code here
sns.relplot(x = 'timepoint', y = 'signal', hue = 'event', kind = 'line', data = fmri)

# %% [markdown]
# Here we have used 4 variables by setting `hue = 'region'` and `style = 'event'`.
#
#
#
#
# ```
# sns.relplot(x = 'timepoint', y = 'signal', hue = 'region', style = 'event', kind = 'line', data = fmri)
# ```

# %%
# Your code here
sns.relplot(x = 'timepoint', y = 'signal', hue = 'region', style = 'event', kind = 'line', data = fmri)

# %% [markdown]
# We can improve the plots by placing markers on the data points by including `markers = True.` We can also remove the dash lines by including` dashes = False`.
#
#
#
# ```
# sns.relplot(x = 'timepoint', y = 'signal', hue = 'region', style = 'event', kind = 'line', data = fmri, markers = True, dashes = False)
# ```

# %%
# Your code here
sns.relplot(x = 'timepoint', y = 'signal', hue = 'region', style = 'event', kind = 'line', 
            data = fmri, markers = True, dashes = False) # event에 등장하는 dash 차이를 없앨 수 있음

# %%
# Your code here
sns.relplot(x = 'timepoint', y = 'signal', hue = 'region', style = 'event', kind = 'line', 
            data = fmri, markers = True, dashes = True)

# %% [markdown]
# We can even set `hue` and `style` to the same variable to emphasize more and make the plots more informative.
#
#
#
# ```
# sns.relplot(x = 'timepoint', y = 'signal', hue = 'event', style = 'event', kind = 'line', data = fmri)
# ```

# %%
# Your code here
sns.relplot(x = 'timepoint', y = 'signal', hue = 'event', style = 'event', kind = 'line', data = fmri)

# %% [markdown]
# We can set units = subject so that each subject will have a separate line in the plot. While selecting the data we can give a condition using fmri.query(). Here we have given the condition that the value of event should be stim.
#
#
#
# ```
# sns.relplot(x = 'timepoint', y = 'signal', hue = 'region', units = 'subject', estimator = None, kind = 'line', data = fmri.query("event == 'stim'"))
# ```

# %%
# Your code here
# unit으로 지정된 항목 기준으로 line이 각각 만들어짐 
sns.relplot(x = 'timepoint', y = 'signal', hue = 'region', units = 'subject', estimator = None, kind = 'line', 
            data = fmri.query("event == 'stim'")) #unit이 있는 경우에는 estimator는 꼭 None이어야 함. 같은 timepoint에서의 값을 표현하기 위해
            #query에는 쿼리문이 ""로 묶여있어야 함!!!!

# %%
# Your code here
sns.relplot(x = 'timepoint', y = 'signal', hue = 'region', estimator = None, kind = 'line', 
            data = fmri.query("event == 'stim'"))

# %%
sns.relplot(x = 'timepoint', y = 'signal', hue = 'region', kind = 'line', 
            data = fmri.query("event == 'stim'"))

# %% [markdown]
# Using `FacetGrid` we can plot` multiple plots` simultaneously. Using col we can specify the categorical variables that will determine the faceting of the grid. Here `col = 'time'` so we are getting two plots for lunch and dinner separately.
#
#
#
# ```
# tips.head()
# ```
#
#
#
# ```
# sns.relplot(x = 'total_bill', y = 'tip', hue = 'smoker', col = 'time', data = tips)
# ```

# %%
# Your code here
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Your code here
sns.relplot(x = 'total_bill', y = 'tip', hue = 'smoker', col = 'time', data = tips) # col을 지정하면 그래프가 나뉨

# %% [markdown]
# Here col = 'day' so we are getting 4 plots for all the days separately.
#
# `col_wrap` wraps the column variable at the given width, so that the column facets span multiple rows.
#
#
#
# ```
# sns.relplot(x = 'total_bill', y = 'tip', hue = 'smoker', col = 'day',data = tips)
# #sns.relplot(x = 'total_bill', y = 'tip', hue = 'smoker', col = 'day', col_wrap=2 ,data = tips)
# ```

# %%
# Your code here
sns.relplot(x = 'total_bill', y = 'tip', hue = 'smoker', col = 'day',data = tips)

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue = 'smoker', col = 'day', col_wrap=2 ,data = tips) # col_wrap은 한줄에 2개 열로 그래프 띄우기

# %% [markdown]
# Now we can plot a 2x2 FacetGrid using row and col. By using height we can set the height (in inches) of each facet.
#
#
#
# ```
# sns.relplot(x = 'total_bill', y = 'tip', hue = 'day',row = 'smoker', col = 'time', height = 3, data = tips)
# ```

# %%
# Your code here
sns.relplot(x = 'total_bill', y = 'tip', hue = 'day',row = 'smoker', col = 'time', height = 5, data = tips)

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue = 'day',row = 'smoker', col = 'time', height = 5, data = tips, aspect = 0.5)
# aspect를 통해 비율을 조정할 수 있음

# %% [markdown]
# We can also plot line plots using sns.lineplot().
#
#
# ```
# sns.lineplot(x = 'total_bill', y = 'tip', data = tips)
# ```
#
#
#
# We can plot scatter plots using sns.scatterplot().
#
#
# ```
# sns.scatterplot(x = 'total_bill', y = 'tip', data = tips)
# ```

# %%
# Your code here
sns.lineplot(x = 'total_bill', y = 'tip', data = tips)

# %%
# Your code here
sns.scatterplot(x = 'total_bill', y = 'tip', data = tips)

# %% [markdown]
# ---
#
# # 2. Categorical Data Plotting

# %% [markdown]
# Now we will see how to plot categorical data.
# ~~~python
# tips.head()
# ~~~

# %%
# Your code here
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# Here `day` has `categorical data` and `total_bill` has `numerical data`.
# ~~~python
# sns.catplot(x = 'day', y = 'total_bill', data = tips)
# ~~~

# %%
# Your code here
sns.catplot(x = 'day', y = 'total_bill', data = tips)

# %% [markdown]
# We can even interchange the variables on `x` and `y` axis to get a horizontal catplot plot.
# ~~~python
# sns.catplot(y = 'day', x = 'total_bill', data = tips)
# ~~~

# %%
# Your code here
sns.catplot(y = 'day', x = 'total_bill', data = tips)

# %% [markdown]
# The `jitter` parameter controls the magnitude of jitter or disables it altogether. Here we have disable the jitter.
# ~~~python
# sns.catplot(x = 'day', y = 'total_bill', data = tips, jitter = False)
# ~~~

# %%
# Your code here
sns.catplot(x = 'day', y = 'total_bill', data = tips, jitter = False) #jitter는 겹치는 점에 대해 파악하기 쉽게 해줌

# %%
# Your code here
sns.catplot(x = 'day', y = 'total_bill', data = tips, jitter = True) #jitter는 겹치는 점에 대해 파악하기 쉽게 해줌

# %% [markdown]
# In `catplot()` we can set the `kind` parameter to `swarm` to avoid overlap of points.
# ~~~python
# sns.catplot(x = 'day', y = 'total_bill', data = tips, kind = 'swarm', hue = 'size')
# ~~~

# %%
# Your code here
sns.catplot(x = 'day', y = 'total_bill', data = tips, kind = 'swarm', hue = 'size') # swarm은 jitter와 비슷하게, 점이 서로 겹치지 않고 분포하게 만듦

# %% [markdown]
# We can set the order in which categorical values should be plotted using `order`. By default categorical levels are inferred from the data objects.
# ~~~python
# sns.catplot(x = 'smoker', y = 'tip', data = tips, order= ['No', 'Yes'])
# ~~~
# If we want detailed characteristics of data we can use `box plot` by setting `kind = 'box'`.

# %%
# Your code here
sns.catplot(x = 'smoker', y = 'tip', data = tips, order= ['No', 'Yes'])

# %%
sns.catplot(x = 'smoker', y = 'tip', data = tips)

# %% [markdown]
# Box plots show the five-number summary of a set of data: including the minimum, first (lower) quartile, median, third (upper) quartile, and maximum.
#
# ![0_r61ywPwYHwbkCFct.jpg](data:image/jpeg;base64,...)
# ~~~python
# sns.catplot(x = 'day', y = 'total_bill', kind = 'box', data = tips, hue = 'sex')
# ~~~

# %%
# Your code here
sns.catplot(x = 'day', y = 'total_bill', kind = 'box', data = tips, hue = 'sex')

# %% [markdown]
# `dodge = False `merges the box plots of categorical values
# ~~~python
# sns.catplot(x = 'day', y = 'total_bill', kind = 'box', data = tips, hue = 'sex', dodge = False)
# ~~~

# %%
# Your code here
sns.catplot(x = 'day', y = 'total_bill', kind = 'box', data = tips, hue = 'sex', dodge = False) #hue에 의해 나눠진 것 다시 합치기

# %% [markdown]
# Now we will load the `diamonds` dataset.
# ~~~python
# diamonds = sns.load_dataset('diamonds')
# diamonds.head()
# ~~~

# %%
# Your code here
diamonds = sns.load_dataset('diamonds')
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# If you want more visualize detailed information you can use boxen plot. It is similar to a box plot in plotting a nonparametric representation of a distribution in which all features correspond to actual observations. By plotting more quantiles, it provides more information about the shape of the distribution, particularly in the tails. While giving the data we are sorting the data according to the colour using `diamonds.sort_values('color')`.
# ~~~python
# sns.catplot(x = 'color', y = 'price', kind = 'boxen', data = diamonds.sort_values('color'))
# ~~~

# %%
diamonds.sort_values('color')
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
# 7817    1.00  Very Good     D     SI2   63.5   59.0   4295  6.35  6.32  4.02
# 7816    1.00       Good     D     SI2   57.8   58.0   4295  6.61  6.55  3.80
# 7815    1.00  Very Good     D     SI2   61.5   63.0   4295  6.32  6.27  3.87
# 7809    0.56      Ideal     D      IF   61.9   57.0   4293  5.28  5.31  3.28
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 4861    1.00    Premium     J     SI1   60.8   58.0   3712  6.39  6.44  3.90
# 18421   1.52      Ideal     J     SI1   61.9   57.0   7491  7.37  7.33  4.55
# 18423   1.50  Very Good     J     VS2   62.6   58.0   7492  7.25  7.29  4.55
# 42108   0.65      Ideal     J     SI1   61.4   55.0   1276  5.58  5.62  3.44
# 14123   1.30      Ideal     J     SI1   61.5   55.0   5728  7.03  7.06  4.33
#
# [53940 rows x 10 columns]

# %%
# Your code here
sns.catplot(x = 'color', y = 'price', kind = 'boxen', data = diamonds.sort_values('color'))

# %% [markdown]
# ~~~python
# sns.catplot(x = 'day', y = 'total_bill', kind = 'boxen', data = tips, dodge = False)
# ~~~

# %%
# Your code here
sns.catplot(x = 'day', y = 'total_bill', kind = 'boxen', data = tips, dodge = False)

# %% [markdown]
# `Violin plot` shows the distribution of quantitative data across several levels of one (or more) categorical variables such that those distributions can be compared. Unlike a box plot, in which all of the plot components correspond to actual data points, the violin plot features a kernel density estimation of the underlying distribution.
#
# We can draw a `violin plo`t by setting `kind = 'violin'`. When using hue nesting with a variable that takes two levels, setting `split` to `True` will draw half of a violin for each level. This can make it easier to directly compare the distributions.
# ~~~python
# sns.catplot(x = 'total_bill', y = 'day', hue = 'sex', kind = 'violin', data = tips, split = True,)
# ~~~

# %%
# Your code here
sns.catplot(x = 'total_bill', y = 'day', hue = 'sex', kind = 'violin', data = tips, split = True,)

# %%
sns.catplot(x = 'total_bill', y = 'day', hue = 'sex', kind = 'violin', data = tips, split = False,)

# %% [markdown]
# Now we will draw the `violin plot` and `swarm plot` together.
#
# `inner = None` enables representation of the datapoints in the violin interior. The value of parameter `ax` represents the axes object to draw the plot onto. Here we have set `ax of swarmplot to g.ax which represents the violin plot`.
# ~~~python
# g = sns.catplot(x = 'day', y = 'total_bill', kind = 'violin', inner = None, data = tips)
# sns.swarmplot(x = 'day', y = 'total_bill', color = 'k', size = 3, data = tips, ax = g.ax)
# ~~~

# %%
# Your code here
g = sns.catplot(x = 'day', y = 'total_bill', kind = 'violin', inner = None, data = tips)
sns.swarmplot(x = 'day', y = 'total_bill', color = 'k', size = 3, data = tips, ax = g.ax)

# %% [markdown]
# Now we will load the `titanic` dataset.
# ~~~python
# titanic = sns.load_dataset('titanic')
# titanic.head()
# ~~~

# %%
# Your code here
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# We will now plot a `barplot`. The black line represents the probability of error.
# ~~~python
# sns.catplot(x = 'sex', y = 'survived', hue = 'class', kind = 'bar', data = titanic)
# ~~~

# %%
# Your code here
sns.catplot(x = 'sex', y = 'survived', hue = 'class', kind = 'bar', data = titanic)

# %% [markdown]
# Now we will plot a `count plot`. We can change the gradient of the colour using `palette` parameter.
# ~~~python
# sns.catplot(x = 'deck', kind = 'count', palette = 'ch:0.95', data = titanic, hue = 'class')
# ~~~

# %%
# Your code here
sns.catplot(x = 'deck', kind = 'count', palette = 'ch:0.95', data = titanic, hue = 'class')

# %% [markdown]
# A `point plot` represents an estimate of central tendency for a numeric variable by the position of scatter plot points and provides some indication of the uncertainty around that estimate using error bars.
# ~~~python
# sns.catplot(x = 'sex', y = 'survived', hue = 'class', kind = 'point', data = titanic)
# ~~~

# %%
# Your code here
sns.catplot(x = 'sex', y = 'survived', hue = 'class', kind = 'point', data = titanic)

# %% [markdown]
# ---
#
# # 3. Visualizing Distribution of the Data

# %% [markdown]
# We can plot univariate distribution using sns.displot(). By default, this will draw a histogram and fit a kernel density estimate (KDE).
# rug draws a small vertical tick at each observation.
#
# randn() returns an array of defined shape, filled with random floating-point samples from the standard normal distribution.
#
#
#
# ```
# x = randn(100)
# sns.displot(x, kde = True, rug= False, bins= 30)
# # sns.displot(x, kde = True, rug= True, bins= 30)
# ```

# %%
# Your code here
# plt의 히스토그램 처럼 seaborn에서는 displot 사용 
x = randn(100)
sns.displot(x, kde = True, rug= False, bins= 30)

# %%
sns.displot(x, kde = True, rug= True, bins= 30) # 가로축 아래 러그 틱이 생김

# %%
sns.displot(x, kde = False, rug= True, bins= 30) # kde는 스무딩한 그래프로 보여줌

# %% [markdown]
# Now lets plot a `kdeplot`.
# `shade = True `shades in the area under the KDE curve. We can control the `bandwidth` using `bw`. The parameter `cut` draws the estimate to cut * bw from the extreme data points i.e. it cuts the plot and zooms it.
#
#
#
# ```
# sns.kdeplot(x, shade=True, cbar = True, bw = 1, cut = 0)
# # sns.kdeplot(x, shade=True, cbar = True, bw = 1)
# ```

# %%
# Your code here
sns.kdeplot(x, shade=True, cbar = True, bw = 1, cut = 0)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Now we will see how to plot bivariate distribution.
#
#
#
# ```
# tips.head()
# ```
#
#
# ```
# x = tips['total_bill']
# y = tips['tip']
#
# sns.jointplot(x = x, y = y)
# ```

# %%
# Your code here
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Your code here
x = tips['total_bill']
y = tips['tip']

sns.jointplot(x = x, y = y)

# %% [markdown]
# By using `kind` we can select the kind of plot to draw. Here we have selected` kind = 'hex'.`
#
#
#
# ```
# sns.set()
# sns.jointplot(x = x, y=y, kind = 'hex')
# ```

# %%
# Your code here
sns.set()
sns.jointplot(x = x, y=y, kind = 'hex')

# %% [markdown]
# Here kind = 'kde'.
#
#
#
# ```
# sns.jointplot(x = x, y = y, kind = 'kde')
# ```

# %%
# Your code here
sns.jointplot(x = x, y = y, kind = 'kde')

# %% [markdown]
# Let's plot this KDE plot in a different way.

# %% [markdown]
# `subplots()` returns the figure and axes.
#
# `sns.cubehelix_palette() `produces a colormap with linearly-decreasing (or increasing) brightness.
#
# `as_cmap = True` returns a matplotlib colormap instead of a list of colors.
#
# The intensity of the darkest and ligtest colours in the palette can be controlled by `dark` and `light`.
#
# As `reverse = True` the palette will go from dark to light.
#
# `sns.kdeplot` will plot a kde plot. `shade = True` shades in the area under the KDE curve.
#
#
#
# ```
# f, ax = plt.subplots(figsize = (6,6))
# cmap = sns.cubehelix_palette(as_cmap = True, dark = 0, light = 1, reverse= True)
# sns.kdeplot(x, y, cmap = cmap, n_levels=60, shade=True, shade_lowest = True)
# ```

# %%
# Your code here
f, ax = plt.subplots(figsize = (6,6))
cmap = sns.cubehelix_palette(as_cmap = True, dark = 0, light = 1, reverse= True)
sns.kdeplot(x, y, cmap = cmap, n_levels=60, shade=True, shade_lowest = True)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:1718: UserWarning: `shade_lowest` is now deprecated in favor of `thresh`. Setting `thresh=0`, but please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# The `jointplot()` function uses a `JointGrid` to manage the figure. For more flexibility, you may want to draw your figure by using `JointGrid` directly. `jointplot()` returns the JointGrid object after plotting, which you can use to add more layers or to tweak other aspects of the visualization.
#
# `sns.plot_joint()` draws a bivariate plot of x and y.` c` and `s` parameters are for `colour` and `size` respectively.
#
#
#
# ```
# g = sns.jointplot(x, y, kind = 'kde', color = 'm', shade=True)
# g.plot_joint(plt.scatter, c = 'w', s = 30, linewidth = 1, marker = '+')
# ```

# %%
# Your code here
g = sns.jointplot(x, y, kind = 'kde', color = 'm', shade=True)
g.plot_joint(plt.scatter, c = 'w', s = 30, linewidth = 1, marker = '+')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Now we will draw `pair plots` using `sns.pairplot()`.
#
# By default, this function will create a grid of Axes such that each numeric variable in data will by shared in the y-axis across a single row and in the x-axis across a single column.
#
# The diagonal Axes are treated differently, drawing a plot to show the univariate distribution of the data for the variable in that column.
#
#
#
# ```
# iris = sns.load_dataset('iris')
# sns.pairplot(iris)
# ```

# %%
# Your code here
iris = sns.load_dataset('iris')
sns.pairplot(iris)

# %% [markdown]
# `map_diag()` draws the diagonal elements are plotted as a `kde plot`. `map_offdiag()` draws the non-diagonal elements as a `kde plot` with `number of levels = 10.`
#
#
#
# ```
# g = sns.PairGrid(iris)
# g.map_diag(sns.kdeplot)
# g.map_offdiag(sns.kdeplot, n_levels = 10)
# ```

# %%
# Your code here
g = sns.PairGrid(iris)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot, n_levels = 10)

# %% [markdown]
# ---
#
# # 4. Linear Regression and Relationship

# %% [markdown]
# ~~~python
# tips.head()
# ~~~

# %%
# Your code here
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# We can draw `regression plots` with the help of `sns.regplot()`. The plot drawn below shows the relationship between `total_bill` and `tip`.
# ~~~python
# sns.regplot(x = 'total_bill', y = 'tip', data = tips)
# ~~~

# %%
# Your code here
sns.regplot(x = 'total_bill', y = 'tip', data = tips)

# %% [markdown]
# We can draw a plot which shows the linear relationship between `size` and `tips`.
# ~~~python
# sns.lmplot(x = 'size', y = 'tip', data = tips, x_jitter = 0.05)
# ~~~

# %%
# Your code here
sns.lmplot(x = 'size', y = 'tip', data = tips, x_jitter = 0.05)

# %%
# Your code here
sns.lmplot(x = 'size', y = 'tip', data = tips)

# %%
# Your code here
sns.lmplot(x = 'size', y = 'tip', data = tips, x_jitter = 0.1)

# %% [markdown]
# If we set `x_estimator = np.mean` the dots in the above plot will be replaced by the mean and a confidence line.
# ~~~python
# sns.lmplot(x = 'size', y = 'tip', data = tips, x_estimator = np.mean)
# ~~~

# %%
# Your code here
sns.lmplot(x = 'size', y = 'tip', data = tips, x_estimator = np.mean)

# %% [markdown]
# Now we will see how to draw a plot for the data which is not linearly related. To do this we will load the `anscombe` dataset.
# ~~~python
# data = sns.load_dataset('anscombe')
# data.head()
# ~~~

# %%
# Your code here
data = sns.load_dataset('anscombe')
data.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %% [markdown]
# This dataset contains 4 types of data and each type contains 11 values.
# ~~~python
# data['dataset'].value_counts()
# ~~~

# %%
# Your code here
# 실제 데이터가 linear 하지 않으면 그래프가 제대로 나오지 않기 때문에 조정해야 함
data['dataset'].value_counts()
# Out:
# I      11
# II     11
# III    11
# IV     11
# Name: dataset, dtype: int64

# %% [markdown]
# Now we will draw a plot for the data of type I from the dataset. `scatter_kws` is used to pass additional keyword arguments.
# ~~~python
# sns.lmplot(x = 'x', y = 'y', data = data.query("dataset == 'I'"), ci = None, scatter_kws={'s': 80})
# ~~~

# %%
# Your code here
sns.lmplot(x = 'x', y = 'y', data = data.query("dataset == 'I'"), ci = None, scatter_kws={'s': 80})
# scatter_kws는 점의 크기를 나타낸 것

# %% [markdown]
# Now we will plot the dataset type II. We can see that it is not a linear relation. In order to fit such type of dataset, we can use the `order` parameter. If an order is greater than 1, it estimates a polynomial regression.
# ~~~python
# sns.lmplot(x = 'x', y = 'y', data = data.query("dataset == 'II'"), ci = None, scatter_kws={'s': 80}, order = 2)
# ~~~

# %%
# Your code here
sns.lmplot(x = 'x', y = 'y', data = data.query("dataset == 'II'"), ci = None, scatter_kws={'s': 80})

# %%
sns.lmplot(x = 'x', y = 'y', data = data.query("dataset == 'II'"), ci = None, scatter_kws={'s': 80}, order = 2)

# %% [markdown]
# Now we will see how to handle `outliers`. An outlier is a data point that differs significantly from other observations. We can go and manually remove the outlier from the dataset or we can set `robust = True` to nullify its effect while drawing the plot.
# ~~~python
# sns.lmplot(x = 'x', y = 'y', data = data.query("dataset == 'III'"), ci = None, scatter_kws={'s': 80}, robust=True)
# ~~~

# %%
# Your code here
sns.lmplot(x = 'x', y = 'y', data = data.query("dataset == 'III'"), ci = None, scatter_kws={'s': 80})

# %%
sns.lmplot(x = 'x', y = 'y', data = data.query("dataset == 'III'"), ci = None, scatter_kws={'s': 80}, robust=True)
# 큰 값을 가지는 outlier에 의해 선형 관계가 틀어지지 않게 제외하고 함수를 구해줌

# %% [markdown]
# We can change the size of figure using `subplots()` and pass the parameter `figsize`.
# ~~~python
# f, ax = plt.subplots(figsize = (8,4))
# sns.regplot(x = 'total_bill', y = 'tip', data = tips, ax = ax)
# ~~~

# %%
print(plt.subplots(figsize = (8,4)))
# Out:
# (<Figure size 576x288 with 1 Axes>, <matplotlib.axes._subplots.AxesSubplot object at 0x7f4d868db4f0>)

# %%
# Your code here
f, ax = plt.subplots(figsize = (8,4))

sns.regplot(x = 'total_bill', y = 'tip', data = tips, ax = ax)

# %% [markdown]
# We can even control the height and the position of the plots using `height` and `col_wrap`.
# ~~~python
# sns.lmplot(x = 'total_bill', y = 'tip', data = tips, col = 'day', col_wrap=2, height = 4)
# ~~~

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = tips, col = 'day', col_wrap = 2, height = 4);

# %% [markdown]
# ---
#
# # 5. Controlling Plotted Figure Aesthetics

# %% [markdown]
# Here is a function to draw a `sinplot`.
# ~~~python
# def sinplot(flip = 1):
#     x = np.linspace(0, 14, 100)
#     for i in range(1,7):
#         plt.plot(x, np.sin(x+i*0.5)*(7-i)*flip)
# sinplot(-1)
# ~~~

# %%
# Style에 대해서 알아볼 건데, 이 스타일이 어떻게 변하는지를 알기 위해
# 간단한 plotting function을 정의해 보자.

def sinplot(flip = 1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 7):
        plt.plot(x, np.sin(x + i * 0.5) * (7 - i) * flip)

sinplot(1)

# %% [markdown]
# `sns.set_style()` is used to set the aesthetic style of the plots. `ticks` will add ticks on the axes. `'axes.grid': True` enables the grid in the background of the plot. `'xtick.direcyion': 'in'` makes the ticks on the x axis to point inwards. `sns.despine()` removes the top and right spines from plot. `left = True` removes the left spine.
# ~~~python
# sns.set_style('ticks', {'axes.grid': True, 'xtick.direction': 'in'})
# sinplot()
# sns.despine(left = True, bottom= False)
# ~~~

# %%
sns.set_style('ticks', {'axes.grid': True, 'xtick.direction': 'in'})
sinplot()

sns.despine(left = False, bottom= False)
# 기본적으로 오른쪽과 위쪽의 축을 없애 준다.
# left = True로 놓음으로써 왼쪽도 없앤 격

# %% [markdown]
# `sns.axes_style()` shows all the current elements which are set on the plot. We can change the values of these elements and customize our plots.
# ~~~python
# sns.axes_style()
# ~~~

# %%
# axes_style로 설정 가능한 style 요소의 목록을 볼 수 있다.
print(sns.axes_style())

# axes.edgecolor = 축 윤곽선 색깔
# grid.linestyle = 그리드 선의 스타일
# xtick.bottom = bottom에 xtick을 나타낼지 여부

sns.set_style("darkgrid", 
              {
                "axes.edgecolor": "0", 
                "grid.linestyle": "-.",
                "xtick.bottom": True
              }
              )
sinplot()
# Out:
# {'axes.facecolor': 'white', 'axes.edgecolor': '.15', 'axes.grid': True, 'axes.axisbelow': True, 'axes.labelcolor': '.15', 'figure.facecolor': 'white', 'grid.color': '.8', 'grid.linestyle': '-', 'text.color': '.15', 'xtick.color': '.15', 'ytick.color': '.15', 'xtick.direction': 'in', 'ytick.direction': 'out', 'lines.solid_capstyle': 'round', 'patch.edgecolor': 'w', 'patch.force_edgecolor': True, 'image.cmap': 'rocket', 'font.family': ['sans-serif'], 'font.sans-serif': ['Arial', 'DejaVu Sans', 'Liberation Sans', 'Bitstream Vera Sans', 'sans-serif'], 'xtick.bottom': True, 'xtick.top': False, 'ytick.left': True, 'ytick.right': False, 'axes.spines.left': True, 'axes.spines.bottom': True, 'axes.spines.right': True, 'axes.spines.top': True}

# %% [markdown]
# `sns.set_context()` sets the plotting context parameters. This affects things like the size of the labels, lines, and other elements of the plot, but not the overall style. The base context is “notebook”, and the other contexts are “paper”, “talk”, and “poster”, which are version of the notebook parameters scaled by .8, 1.3, and 1.6, respectively. We can even use `font_scale` which is a separate scaling factor to independently scale the size of the font elements.
# ~~~python
# sns.set_style('darkgrid')
# sns.set_context('talk', font_scale=1.5)
# sinplot()
# ~~~

# %%
sns.set_style('darkgrid')
sns.set_context('notebook', font_scale=1)
sinplot()

# %% [markdown]
# Now we will see some `colour palettes `which `seaborn` uses. `sns.color_palette()` returns a list of the current colors defining a color palette.
# ~~~python
# current_palettes = sns.color_palette()
# sns.palplot(current_palettes)
# ~~~

# %%
current_palettes = sns.color_palette()
sns.palplot(current_palettes)

# %% [markdown]
# We can use the the `hls` color space, which is a simple transformation of `RGB` values to create colour palettes.
# ~~~python
# sns.palplot(sns.color_palette('hls', 8))
# ~~~

# %%
sns.palplot(sns.color_palette('hls', 8))

# %%
sns.palplot(sns.color_palette('hls', 10))
